# %%
# !pip install wandb -qqq
import wandb
import pprint

# %%
# !pip install wandb --upgrade --user
# Out:
# Requirement already up-to-date: wandb in c:\users\desktop\appdata\roaming\python\python38\site-packages (0.10.33)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from wandb) (2.24.0)
# Requirement already satisfied, skipping upgrade: psutil>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from wandb) (5.7.2)
# Requirement already satisfied, skipping upgrade: shortuuid>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from wandb) (1.0.1)
# Requirement already satisfied, skipping upgrade: protobuf>=3.12.0 in c:\programdata\anaconda3\lib\site-packages (from wandb) (3.17.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in c:\programdata\anaconda3\lib\site-packages (from wandb) (2.8.1)
# Requirement already satisfied, skipping upgrade: docker-pycreds>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from wandb) (0.4.0)
# Requirement already satisfied, skipping upgrade: sentry-sdk>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from wandb) (1.1.0)
# Requirement already satisfied, skipping upgrade: promise<3,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from wandb) (2.3)
# Requirement already satisfied, skipping upgrade: Click!=8.0.0,>=7.0 in c:\programdata\anaconda3\lib\site-packages (from wandb) (7.1.2)
# Requirement already satisfied, skipping upgrade: subprocess32>=3.5.3 in c:\programdata\anaconda3\lib\site-packages (from wandb) (3.5.4)
# Requirement already satisfied, skipping upgrade: pathtools in c:\programdata\anaconda3\lib\site-packages (from wandb) (0.1.2)
# Requirement already satisfied, skipping upgrade: urllib3<=1.25.11; sys_platform == "win32" or sys_platform == "cygwin" in c:\programdata\anaconda3\lib\site-packages (from wandb) (1.25.11)
# Requirement already satisfied, skipping upgrade: six>=1.13.0 in c:\programdata\anaconda3\lib\site-packages (from wandb) (1.15.0)
# Requirement already satisfied, skipping upgrade: GitPython>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from wandb) (3.1.18)
# Requirement already satisfied, skipping upgrade: PyYAML in c:\programdata\anaconda3\lib\site-packages (from wandb) (5.3.1)
# Requirement already satisfied, skipping upgrade: configparser>=3.8.1 in c:\programdata\anaconda3\lib\site-packages (from wandb) (5.0.2)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (2020.6.20)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied, skipping upgrade: gitdb<5,>=4.0.1 in c:\programdata\anaconda3\lib\site-packages (from GitPython>=1.0.0->wandb) (4.0.7)
# Requirement already satisfied, skipping upgrade: smmap<5,>=3.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (4.0.0)

# %%
sweep_config = {
    'method': 'bayes'
}

metric={
      'goal': 'maximize',
      'name': 'account'
}

sweep_config['metric'] = metric

parameters_dict = {
}

sweep_config['parameters'] = parameters_dict

parameters_dict.update({
    'n_period': {
        'max': 30, # 1 ~ 갯수의 평균x2 까지
        'min': 3
    },
      'K_long': {
        'distribution': 'uniform',
        'max': 2.0, # 평균 비율 ~ X2 까지
        'min': 1.0
      },
      'k_short': {
        'distribution': 'uniform',
        'max': 2.0 , # 1 ~ 평균 까지
        'min': 1.0
      }
})


pprint.pprint(sweep_config)
# Out:
# {'method': 'bayes',
#  'metric': {'goal': 'maximize', 'name': 'account'},
#  'parameters': {'K_long': {'distribution': 'uniform', 'max': 2.0, 'min': 1.0},
#                 'k_short': {'distribution': 'uniform', 'max': 2.0, 'min': 1.0},
#                 'n_period': {'max': 30, 'min': 3}}}

# %%
# 테마주

name = ["SK바이오팜","씨젠","오스템임플란트","차바이오텍","헬릭스미스","메지온","에이치엘비생명과학","대웅","녹십자홀딩스",
"동국제약","CMG제약","영진약품","엘앤씨바이오","메디포스트","제테마","코미팜","엔케이맥스","바디텍메드","JW중외제약","클래시스","종근당홀딩스",
"유틸렉스","서흥","티움바이오","카이노스메드","앱클론","아이센스","EDGC","에이프로젠제약","바텍","삼진제약","동화약품","수젠텍","제일약품",
"뷰웍스","테라젠이텍스","한독","케어젠","대원제약","유비케어","일동제약","동성제약","지노믹트리","제일파마홀딩스","휴마시스","환인제약","팜젠사이언스","파미셀","진원생명과학","종근당바이오","종근당","제넥신","일양약품","이연제약","유나이티드제약","오리엔트바이오","셀트리온제약","삼천당제약","삼성제약","삼성바이오로직스","부광약품","명문제약","대웅제약","녹십자","국제약품","광동제약","고려제약","경보제약",
     "메디톡스","아미코젠","인트론바이오","알테오젠","오스코텍","한미사이언스","바이오니아","레고켐바이오","셀트리온","셀트리온헬스케어","에이비엘바이오","삼천당제약","안트로젠",
"압타바이오","유바이오로직스","보령제약","한국파마","파마리서치","엔지켐생명과학","KPX생명과학","에스티팜","휴온스","한미약품","한올바이오파마","지트리비앤티","녹십자랩셀","올릭스",
"크리스탈지노믹스","휴젤","셀리버리","이수앱지스","메드팩토","바이넥스","휴메딕스","휴온스글로벌"]


sweep_id = wandb.sweep(sweep_config, project=f"dual_SK바이오팜_분단위_논문_최대60")

wandb.agent(sweep_id, train_theme, count=100)
# Out:
# Create sweep with ID: 8390szpg
# Sweep URL: https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/sweeps/8390szpg
# wandb: Agent Starting Run: cxb8tzk6 with config:
# wandb: 	K_long: 1.1928822943621233
# wandb: 	k_short: 1.585723418851563
# wandb: 	n_period: 20
# wandb: Currently logged in as: yeongu (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.33<br/>
#                 Syncing run <strong style="color:#cdcd00">eternal-sweep-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060</a><br/>
#                 Sweep page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/sweeps/8390szpg" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/sweeps/8390szpg</a><br/>
# Run page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/cxb8tzk6" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/cxb8tzk6</a><br/>
#                 Run data is saved locally in <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_110408-cxb8tzk6</code><br/><br/>
# ======================
# 20200707
# 902
# 구매가 :  224190.91736023768
# 구매갯수 :  44
# 현재가격 : 9864387.4362
# 나머지 :  135640
# ======================
# ======================
# 20200713
# 903
# 판매가 :  203328.55316229688
# 판매갯수 :  44
# 현재잔고 :  9023920.192
# ======================
# ======================
# 20200714
# 902
# 구매가 :  201223.06122670628
# 구매갯수 :  44.0
# 현재가격 : 8853775.8672
# 나머지 :  170108.1919999998
# ======================
# ======================
# 20200721
# 1444
# 판매가 :  185207.13829057422
# 판매갯수 :  44.0
# 현재잔고 :  8266246.99
# ======================
# ======================
# 20200728
# 1122
# 구매가 :  190124.95561335314
# 구매갯수 :  43.0
# 현재가격 : 8175354.119200001
# 나머지 :  90914.99000000022
# ======================
# ======================
# 20200729
# 902
# 판매가 :  188914.27658114844
# 판매갯수 :  43.0
# 현재잔고 :  8161415.527000001
# ======================
# ======================
# 20200803
# 901
# 구매가 :  175219.1612267063
# 구매갯수 :  46.0
# 현재가격 : 8060040.8248000005
# 나머지 :  101341.5270000007
# ======================
# ======================
# 20200803
# 1454
# 판매가 :  174707.13829057422
# 판매갯수 :  46.0
# 현재잔고 :  8085626.1340000015
# ======================
# ======================
# 20200807
# 1259
# 구매가 :  179123.30561335315
# 구매갯수 :  45.0
# 현재가격 : 8060528.898000001
# 나머지 :  25091.134000001475
# ======================
# ======================
# 20200811
# 1213
# 판매가 :  192707.13829057422
# 판매갯수 :  45.0
# 현재잔고 :  8640539.336500002
# ======================
# ======================
# 20200814
# 1226
# 구매가 :  179623.38061335316
# 구매갯수 :  48.0
# 현재가격 : 8621901.091200002
# 나머지 :  18635.33650000207
# ======================
# ======================
# 20200814
# 1308
# 판매가 :  179207.13829057422
# 판매갯수 :  48.0
# 현재잔고 :  8564658.752500003
# ======================
# ======================
# 20200818
# 1247
# 구매가 :  176622.93061335315
# 구매갯수 :  48.0
# 현재가격 : 8477879.4912
# 나머지 :  86802.7525000032
# ======================
# ======================
# 20200826
# 1326
# 판매가 :  172207.13829057422
# 판매갯수 :  48.0
# 현재잔고 :  8299010.168500003
# ======================
# ======================
# 20200828
# 901
# 구매가 :  168121.65561335316
# 구매갯수 :  49.0
# 현재가격 : 8237939.505600001
# 나머지 :  61081.168500003405
# ======================
# ======================
# 20200831
# 901
# 판매가 :  169207.13829057422
# 판매갯수 :  49.0
# 현재잔고 :  8298331.739000004
# ======================
# ======================
# 20200901
# 1237
# 구매가 :  170718.4862267063
# 구매갯수 :  48.0
# 현재가격 : 8194444.982400001
# 나머지 :  103867.73900000378
# ======================
# ======================
# 20200908
# 1314
# 판매가 :  189207.13829057422
# 판매갯수 :  48.0
# 현재잔고 :  9126771.155000005
# ======================
# ======================
# 20200910
# 1357
# 구매가 :  190221.4112267063
# 구매갯수 :  47.0
# 현재가격 : 8940364.853600001
# 나머지 :  186384.15500000492
# ======================
# ======================
# 20200911
# 1244
# 판매가 :  174707.13829057422
# 판매갯수 :  47.0
# 현재잔고 :  8344240.166500005
# ======================
# ======================
# 20200915
# 1223
# 구매가 :  172122.25561335316
# 구매갯수 :  48.0
# 현재가격 : 8261847.091200001
# 나머지 :  82384.16650000494
# ======================
# ======================
# 20200918
# 1247
# 판매가 :  169707.13829057422
# 판매갯수 :  48.0
# 현재잔고 :  8175371.582500005
# ======================
# ======================
# 20200923
# 1501
# 구매가 :  161620.68061335315
# 구매갯수 :  50.0
# 현재가격 : 8081011.970000001
# 나머지 :  94371.58250000514
# ======================
# ======================
# 20200928
# 1102
# 판매가 :  157207.13829057422
# 판매갯수 :  50.0
# 현재잔고 :  7903629.307500006
# ======================
# ======================
# 20201005
# 901
# 구매가 :  145618.28061335316
# 구매갯수 :  54.0
# 현재가격 : 7863363.3276
# 나머지 :  40257.3075000057
# ======================
# ======================
# 20201006
# 1340
# 판매가 :  140707.13829057422
# 판매갯수 :  54.0
# 현재잔고 :  7589047.150500006
# ======================
# ======================
# 20201006
# 1447
# 구매가 :  140617.53061335316
# 구매갯수 :  53.0
# 현재가격 : 7452705.7382000005
# 나머지 :  136346.15050000604
# ======================
# ======================
# 20201008
# 1504
# 판매가 :  146707.13829057422
# 판매갯수 :  53.0
# 현재잔고 :  7861276.589000006
# ======================
# ======================
# 20201014
# 903
# 구매가 :  167718.0362267063
# 구매갯수 :  46.0
# 현재가격 : 7714989.0748000005
# 나머지 :  146248.5890000062
# ======================
# ======================
# 20201015
# 1308
# 판매가 :  147707.13829057422
# 판매갯수 :  46.0
# 현재잔고 :  6896606.196000007
# ======================
# ======================
# 20201019
# 901
# 구매가 :  152812.24184005943
# 구매갯수 :  45.0
# 현재가격 : 6876536.325750001
# 나머지 :  20066.19600000698
# ======================
# ======================
# 20201019
# 1359
# 판매가 :  153207.13829057422
# 판매갯수 :  45.0
# 현재잔고 :  6869568.148500008
# ======================
# ======================
# 20201021
# 957
# 구매가 :  155119.70561335314
# 구매갯수 :  44.0
# 현재가격 : 6825247.6336
# 나머지 :  44332.14850000758
# ======================
# ======================
# 20201027
# 1126
# 판매가 :  158207.13829057422
# 판매갯수 :  44.0
# 현재잔고 :  6960192.946500008
# ======================
# ======================
# 20201029
# 901
# 구매가 :  155119.70561335314
# 구매갯수 :  44.0
# 현재가격 : 6825247.6336
# 나머지 :  134956.946500008
# ======================
# ======================
# 20201103
# 1207
# 판매가 :  158707.13829057422
# 판매갯수 :  44.0
# 현재잔고 :  7072674.744500008
# ======================
# ======================
# 20201110
# 1047
# 구매가 :  166121.35561335314
# 구매갯수 :  42.0
# 현재가격 : 6977078.404800001
# 나머지 :  95592.74450000841
# ======================
# ======================
# 20201112
# 1459
# 판매가 :  163207.13829057422
# 판매갯수 :  42.0
# 현재잔고 :  6905731.2335000085
# ======================
# ======================
# 20201113
# 1127
# 구매가 :  164621.13061335316
# 구매갯수 :  41.0
# 현재가격 : 6749448.265400001
# 나머지 :  156270.23350000847
# ======================
# ======================
# 20201119
# 1518
# 판매가 :  169707.13829057422
# 판매갯수 :  41.0
# 현재잔고 :  7069030.318000008
# ======================
# ======================
# 20201120
# 1329
# 구매가 :  170121.95561335314
# 구매갯수 :  41.0
# 현재가격 : 6974982.090400001
# 나머지 :  94069.31800000835
# ======================
# ======================
# 20201126
# 1055
# 판매가 :  177207.13829057422
# 판매갯수 :  41.0
# 현재잔고 :  7312330.652500009
# ======================
# ======================
# 20201201
# 1427
# 구매가 :  178623.23061335317
# 구매갯수 :  40.0
# 현재가격 : 7144911.576
# 나머지 :  167410.65250000916
# ======================
# ======================
# 20201207
# 1401
# 판매가 :  172707.13829057422
# 판매갯수 :  40.0
# 현재잔고 :  7030786.83250001
# ======================
# ======================
# 20201210
# 1441
# 구매가 :  172622.33061335314
# 구매갯수 :  40.0
# 현재가격 : 6904875.576
# 나머지 :  125906.8325000098
# ======================
# ======================
# 20201211
# 1221
# 판매가 :  174707.13829057422
# 판매갯수 :  40.0
# 현재잔고 :  7068763.01250001
# ======================
# ======================
# 20201215
# 1459
# 구매가 :  170622.03061335316
# 구매갯수 :  41.0
# 현재가격 : 6995485.1654
# 나머지 :  73261.01250001043
# ======================
# ======================
# 20201222
# 1422
# 판매가 :  173207.13829057422
# 판매갯수 :  41.0
# 현재잔고 :  7128588.347000011
# ======================
# ======================
# 20201224
# 1520
# 구매가 :  170622.03061335316
# 구매갯수 :  41.0
# 현재가격 : 6995485.1654
# 나머지 :  133086.34700001124
# ======================
# ======================
# 20201228
# 1211
# 판매가 :  168207.13829057422
# 판매갯수 :  41.0
# 현재잔고 :  6984746.181500011
# ======================
# ======================
# 20201229
# 1456
# 구매가 :  168121.65561335316
# 구매갯수 :  41.0
# 현재가격 : 6892969.7904
# 나머지 :  91785.18150001112
# ======================
# ======================
# 20210111
# 1313
# 판매가 :  155207.13829057422
# 판매갯수 :  41.0
# 현재잔고 :  6413909.516000011
# ======================
# ======================
# 20210111
# 1346
# 구매가 :  155619.78061335316
# 구매갯수 :  41.0
# 현재가격 : 6380392.9154
# 나머지 :  33530.516000011005
# ======================
# ======================
# 20210126
# 901
# 판매가 :  152207.13829057422
# 판매갯수 :  41.0
# 현재잔고 :  6233454.350500011
# ======================
# ======================
# 20210127
# 901
# 구매가 :  152619.33061335314
# 구매갯수 :  40.0
# 현재가격 : 6104755.576
# 나머지 :  128694.35050001089
# ======================
# ======================
# 20210128
# 1141
# 판매가 :  148707.13829057422
# 판매갯수 :  40.0
# 현재잔고 :  6038310.5305000115
# ======================
# ======================
# 20210129
# 1518
# 구매가 :  145618.28061335316
# 구매갯수 :  41.0
# 현재가격 : 5970331.4154
# 나머지 :  67972.53050001152
# ======================
# ======================
# 20210203
# 1455
# 판매가 :  149207.13829057422
# 판매갯수 :  41.0
# 현재잔고 :  6145695.865000011
# ======================
# ======================
# 20210204
# 1318
# 구매가 :  148118.65561335316
# 구매갯수 :  41.0
# 현재가격 : 6072846.7904
# 나머지 :  72857.8650000114
# ======================
# ======================
# 20210209
# 929
# 판매가 :  149207.13829057422
# 판매갯수 :  41.0
# 현재잔고 :  6150581.199500011
# ======================
# ======================
# 20210209
# 1408
# 구매가 :  150118.95561335314
# 구매갯수 :  40.0
# 현재가격 : 6004740.576
# 나머지 :  145861.19950001128
# ======================
# ======================
# 20210219
# 1329
# 판매가 :  148207.13829057422
# 판매갯수 :  40.0
# 현재잔고 :  6035607.379500012
# ======================
# ======================
# 20210225
# 1517
# 구매가 :  125115.20561335314
# 구매갯수 :  48.0
# 현재가격 : 6005508.6912
# 나머지 :  30087.379500011913
# ======================
# ======================
# 20210226
# 1110
# 판매가 :  119207.13829057422
# 판매갯수 :  48.0
# 현재잔고 :  5714830.795500012
# ======================
# ======================
# 20210302
# 1229
# 구매가 :  115113.70561335314
# 구매갯수 :  49.0
# 현재가격 : 5640549.955600001
# 나머지 :  74293.79550001211
# ======================
# ======================
# 20210302
# 1507
# 판매가 :  112707.13829057422
# 판매갯수 :  49.0
# 현재잔고 :  5561039.6160000125
# ======================
# ======================
# 20210303
# 1457
# 구매가 :  113113.40561335314
# 구매갯수 :  49.0
# 현재가격 : 5542535.255600001
# 나머지 :  18502.616000012495
# ======================
# ======================
# 20210305
# 901
# 판매가 :  109207.13829057422
# 판매갯수 :  49.0
# 현재잔고 :  5334863.186500013
# ======================
# ======================
# 20210305
# 1255
# 구매가 :  109612.88061335315
# 구매갯수 :  48.0
# 현재가격 : 5261397.091200001
# 나머지 :  73487.18650001287
# ======================
# ======================
# 20210308
# 1102
# 판매가 :  110207.13829057422
# 판매갯수 :  48.0
# 현재잔고 :  5329038.602500013
# ======================
# ======================
# 20210312
# 924
# 구매가 :  108709.18622670628
# 구매갯수 :  49.0
# 현재가격 : 5326706.8862000005
# 나머지 :  2297.6025000130758
# ======================
# ======================
# 20210315
# 1222
# 판매가 :  109207.13829057422
# 판매갯수 :  49.0
# 현재잔고 :  5318658.173000013
# ======================
# 5318658.17
# <br/>Waiting for W&B process to finish, PID 4624<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_110408-cxb8tzk6\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_110408-cxb8tzk6\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>account</td><td>5318658.173</td></tr><tr><td>_runtime</td><td>36</td></tr><tr><td>_timestamp</td><td>1625623485</td></tr><tr><td>_step</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>account</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">eternal-sweep-1</strong>: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/cxb8tzk6" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/cxb8tzk6</a><br/>
# wandb: Agent Starting Run: ggudn2lx with config:
# wandb: 	K_long: 1.394554521099228
# wandb: 	k_short: 1.03276622733393
# wandb: 	n_period: 25
#                 Tracking run with wandb version 0.10.33<br/>
#                 Syncing run <strong style="color:#cdcd00">misunderstood-sweep-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060</a><br/>
#                 Sweep page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/sweeps/8390szpg" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/sweeps/8390szpg</a><br/>
# Run page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/ggudn2lx" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/ggudn2lx</a><br/>
#                 Run data is saved locally in <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_110449-ggudn2lx</code><br/><br/>
# ======================
# 20200707
# 902
# 구매가 :  225401.1322256644
# 구매갯수 :  44
# 현재가격 : 9917635.422200002
# 나머지 :  82356
# ======================
# ======================
# 20200707
# 1454
# 판매가 :  217450.85065899912
# 판매갯수 :  44
# 현재잔고 :  9587965.3
# ======================
# ======================
# 20200721
# 901
# 구매가 :  187922.7387042774
# 구매갯수 :  51.0
# 현재가격 : 9584031.3891
# 나머지 :  3943.300000000745
# ======================
# ======================
# 20200721
# 1444
# 판매가 :  185483.61688633304
# 판매갯수 :  51.0
# 현재잔고 :  9402088.685500002
# ======================
# ======================
# 20200728
# 1122
# 구매가 :  190225.80685213872
# 구매갯수 :  49.0
# 현재가격 : 9321050.947950002
# 나머지 :  81063.68550000153
# ======================
# ======================
# 20200729
# 902
# 판매가 :  189467.23377266608
# 판매갯수 :  49.0
# 현재잔고 :  9304601.446000002
# ======================
# ======================
# 20200803
# 901
# 구매가 :  175420.8637042774
# 구매갯수 :  53.0
# 현재가격 : 9297276.3823
# 나머지 :  7341.446000002325
# ======================
# ======================
# 20200804
# 1448
# 판매가 :  175983.61688633304
# 판매갯수 :  53.0
# 현재잔고 :  9273814.302500002
# ======================
# ======================
# 20200807
# 1259
# 구매가 :  179224.15685213872
# 구매갯수 :  51.0
# 현재가격 : 9140417.857050002
# 나머지 :  133390.3025000021
# ======================
# ======================
# 20200811
# 1213
# 판매가 :  192983.61688633304
# 판매갯수 :  51.0
# 현재잔고 :  9911549.438000003
# ======================
# ======================
# 20200814
# 1226
# 구매가 :  179724.23185213874
# 구매갯수 :  55.0
# 현재가격 : 9884817.50025
# 나머지 :  26729.438000002876
# ======================
# ======================
# 20200818
# 901
# 판매가 :  173967.23377266608
# 판매갯수 :  55.0
# 현재잔고 :  9532721.235500004
# ======================
# ======================
# 20200818
# 1247
# 구매가 :  176723.78185213872
# 구매갯수 :  53.0
# 현재가격 : 9366345.741150001
# 나머지 :  166402.23550000414
# ======================
# ======================
# 20200826
# 1326
# 판매가 :  172483.61688633304
# 판매갯수 :  53.0
# 현재잔고 :  9248580.842000004
# ======================
# ======================
# 20200828
# 901
# 구매가 :  168222.50685213873
# 구매갯수 :  54.0
# 현재가격 : 9084000.3957
# 나머지 :  164592.8420000039
# ======================
# ======================
# 20200831
# 901
# 판매가 :  169483.61688633304
# 판매갯수 :  54.0
# 현재잔고 :  9257186.309000004
# ======================
# ======================
# 20200901
# 1237
# 구매가 :  170920.18870427742
# 구매갯수 :  54.0
# 현재가격 : 9229660.241400002
# 나머지 :  27506.309000004083
# ======================
# ======================
# 20200908
# 1314
# 판매가 :  189483.61688633304
# 판매갯수 :  54.0
# 현재잔고 :  10193079.776000004
# ======================
# ======================
# 20200910
# 1357
# 구매가 :  190423.1137042774
# 구매갯수 :  53.0
# 현재가격 : 10092395.6323
# 나머지 :  100660.77600000426
# ======================
# ======================
# 20200911
# 1355
# 판매가 :  173967.23377266608
# 판매갯수 :  53.0
# 현재잔고 :  9260980.144500004
# ======================
# ======================
# 20200915
# 1223
# 구매가 :  172223.10685213874
# 구매갯수 :  53.0
# 현재가격 : 9127809.96615
# 나머지 :  133161.14450000413
# ======================
# ======================
# 20200918
# 1247
# 판매가 :  169983.61688633304
# 판매갯수 :  53.0
# 현재잔고 :  9083701.001000004
# ======================
# ======================
# 20200923
# 1501
# 구매가 :  161721.53185213872
# 구매갯수 :  56.0
# 현재가격 : 9056390.254800001
# 나머지 :  27325.00100000389
# ======================
# ======================
# 20200928
# 1102
# 판매가 :  157483.61688633304
# 판매갯수 :  56.0
# 현재잔고 :  8789049.189000005
# ======================
# ======================
# 20201006
# 1129
# 구매가 :  141218.4568521387
# 구매갯수 :  62.0
# 현재가격 : 8755527.132100001
# 나머지 :  33533.1890000049
# ======================
# ======================
# 20201006
# 1340
# 판매가 :  140983.61688633304
# 판매갯수 :  62.0
# 현재잔고 :  8717663.040000005
# ======================
# ======================
# 20201006
# 1447
# 구매가 :  140718.38185213873
# 구매갯수 :  61.0
# 현재가격 : 8583804.37755
# 나머지 :  133865.0400000047
# ======================
# ======================
# 20201015
# 1308
# 판매가 :  147983.61688633304
# 판매갯수 :  61.0
# 현재잔고 :  9102152.780500006
# ======================
# ======================
# 20201021
# 957
# 구매가 :  155220.55685213872
# 구매갯수 :  58.0
# 현재가격 : 9002776.213900002
# 나머지 :  99392.78050000593
# ======================
# ======================
# 20201027
# 1126
# 판매가 :  158483.61688633304
# 판매갯수 :  58.0
# 현재잔고 :  9231658.689500006
# ======================
# ======================
# 20201029
# 901
# 구매가 :  155220.55685213872
# 구매갯수 :  59.0
# 현재가격 : 9157996.49345
# 나머지 :  73678.68950000592
# ======================
# ======================
# 20201106
# 1123
# 판매가 :  168483.61688633304
# 판매갯수 :  59.0
# 현재잔고 :  9949562.459000006
# ======================
# ======================
# 20201112
# 1409
# 구매가 :  163721.8318521387
# 구매갯수 :  60.0
# 현재가격 : 9823293.273
# 나머지 :  126302.45900000632
# ======================
# ======================
# 20201112
# 1459
# 판매가 :  163483.61688633304
# 판매갯수 :  60.0
# 현재잔고 :  9871524.089000007
# ======================
# ======================
# 20201113
# 1127
# 구매가 :  164721.98185213874
# 구매갯수 :  59.0
# 현재가격 : 9718580.56845
# 나머지 :  152985.08900000714
# ======================
# ======================
# 20201119
# 1518
# 판매가 :  169983.61688633304
# 판매갯수 :  59.0
# 현재잔고 :  10116793.608500008
# ======================
# ======================
# 20201120
# 1329
# 구매가 :  170222.80685213872
# 구매갯수 :  59.0
# 현재가격 : 10043129.24345
# 나머지 :  73695.60850000754
# ======================
# ======================
# 20201126
# 1055
# 판매가 :  177483.61688633304
# 판매갯수 :  59.0
# 현재잔고 :  10477127.878000008
# ======================
# ======================
# 20201201
# 1427
# 구매가 :  178724.08185213874
# 구매갯수 :  58.0
# 현재가격 : 10365980.663900001
# 나머지 :  111135.87800000794
# ======================
# ======================
# 20201207
# 1401
# 판매가 :  172983.61688633304
# 판매갯수 :  58.0
# 현재잔고 :  10078935.287000008
# ======================
# ======================
# 20201210
# 1441
# 구매가 :  172723.18185213872
# 구매갯수 :  58.0
# 현재가격 : 10017928.463900002
# 나머지 :  61001.28700000793
# ======================
# ======================
# 20201211
# 1221
# 판매가 :  174983.61688633304
# 판매갯수 :  58.0
# 현재잔고 :  10144046.696000008
# ======================
# ======================
# 20201215
# 1459
# 구매가 :  170722.88185213873
# 구매갯수 :  59.0
# 현재가격 : 10072633.668450002
# 나머지 :  71448.69600000791
# ======================
# ======================
# 20201222
# 1422
# 판매가 :  173483.61688633304
# 판매갯수 :  59.0
# 현재잔고 :  10240414.965500008
# ======================
# ======================
# 20201224
# 1520
# 구매가 :  170722.88185213873
# 구매갯수 :  59.0
# 현재가격 : 10072633.668450002
# 나머지 :  167816.96550000831
# ======================
# ======================
# 20201228
# 1211
# 판매가 :  168483.61688633304
# 판매갯수 :  59.0
# 현재잔고 :  10043700.735000009
# ======================
# ======================
# 20201229
# 1456
# 구매가 :  168222.50685213873
# 구매갯수 :  59.0
# 현재가격 : 9925111.543450002
# 나머지 :  118602.73500000872
# ======================
# ======================
# 20210111
# 901
# 판매가 :  157967.23377266608
# 판매갯수 :  59.0
# 현재잔고 :  9378075.390500009
# ======================
# ======================
# 20210111
# 1346
# 구매가 :  155720.63185213873
# 구매갯수 :  60.0
# 현재가격 : 9343221.273
# 나머지 :  34875.39050000906
# ======================
# ======================
# 20210114
# 902
# 판매가 :  152967.23377266608
# 판매갯수 :  60.0
# 현재잔고 :  9153238.26050001
# ======================
# ======================
# 20210114
# 1501
# 구매가 :  155220.55685213872
# 구매갯수 :  58.0
# 현재가격 : 9002776.213900002
# 나머지 :  150478.2605000101
# ======================
# ======================
# 20210126
# 901
# 판매가 :  152483.61688633304
# 판매갯수 :  58.0
# 현재잔고 :  8937006.16950001
# ======================
# ======================
# 20210127
# 901
# 구매가 :  152720.18185213872
# 구매갯수 :  58.0
# 현재가격 : 8857754.463900002
# 나머지 :  79246.16950001009
# ======================
# ======================
# 20210129
# 901
# 판매가 :  148483.61688633304
# 판매갯수 :  58.0
# 현재잔고 :  8635282.07850001
# ======================
# ======================
# 20210129
# 1518
# 구매가 :  145719.13185213873
# 구매갯수 :  59.0
# 현재가격 : 8597412.418450002
# 나머지 :  37861.07850001007
# ======================
# ======================
# 20210201
# 1247
# 판매가 :  147467.23377266608
# 판매갯수 :  59.0
# 현재잔고 :  8681860.48400001
# ======================
# ======================
# 20210201
# 1320
# 구매가 :  150219.80685213872
# 구매갯수 :  57.0
# 현재가격 : 8562513.18435
# 나머지 :  119377.48400001042
# ======================
# ======================
# 20210203
# 1455
# 판매가 :  149483.61688633304
# 판매갯수 :  57.0
# 현재잔고 :  8584525.03250001
# ======================
# ======================
# 20210204
# 1318
# 구매가 :  148219.50685213873
# 구매갯수 :  57.0
# 현재가격 : 8448496.084350001
# 나머지 :  136042.03250000998
# ======================
# ======================
# 20210209
# 929
# 판매가 :  149483.61688633304
# 판매갯수 :  57.0
# 현재잔고 :  8601189.58100001
# ======================
# ======================
# 20210209
# 1408
# 구매가 :  150219.80685213872
# 구매갯수 :  57.0
# 현재가격 : 8562513.18435
# 나머지 :  38706.58100000955
# ======================
# ======================
# 20210219
# 1329
# 판매가 :  148483.61688633304
# 판매갯수 :  57.0
# 현재잔고 :  8447224.62950001
# ======================
# ======================
# 20210303
# 1457
# 구매가 :  113214.2568521387
# 구매갯수 :  74.0
# 현재가격 : 8377834.486700001
# 나머지 :  69388.62950000912
# ======================
# ======================
# 20210305
# 901
# 판매가 :  109483.61688633304
# 판매갯수 :  74.0
# 현재잔고 :  8118469.306500009
# ======================
# ======================
# 20210305
# 1255
# 구매가 :  109713.7318521387
# 구매갯수 :  73.0
# 현재가격 : 8009082.182150001
# 나머지 :  109420.30650000926
# ======================
# ======================
# 20210308
# 1102
# 판매가 :  110483.61688633304
# 판매갯수 :  73.0
# 현재잔고 :  8122255.12300001
# ======================
# ======================
# 20210312
# 1508
# 구매가 :  108713.58185213871
# 구매갯수 :  74.0
# 현재가격 : 8044784.536700001
# 나머지 :  77493.12300000992
# ======================
# ======================
# 20210315
# 1222
# 판매가 :  109483.61688633304
# 판매갯수 :  74.0
# 현재잔고 :  8126573.80000001
# ======================
# 8126573.8
# <br/>Waiting for W&B process to finish, PID 9400<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_110449-ggudn2lx\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_110449-ggudn2lx\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>account</td><td>8126573.8</td></tr><tr><td>_runtime</td><td>43</td></tr><tr><td>_timestamp</td><td>1625623532</td></tr><tr><td>_step</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>account</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">misunderstood-sweep-2</strong>: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/ggudn2lx" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/ggudn2lx</a><br/>
# wandb: Agent Starting Run: 11evwwbi with config:
# wandb: 	K_long: 1.431295751372546
# wandb: 	k_short: 1.0397239698283842
# wandb: 	n_period: 24
#                 Tracking run with wandb version 0.10.33<br/>
#                 Syncing run <strong style="color:#cdcd00">grateful-sweep-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060</a><br/>
#                 Sweep page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/sweeps/8390szpg" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/sweeps/8390szpg</a><br/>
# Run page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/11evwwbi" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/11evwwbi</a><br/>
#                 Run data is saved locally in <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_110537-11evwwbi</code><br/><br/>
# ======================
# 20200707
# 902
# 구매가 :  225621.61267441153
# 구매갯수 :  44
# 현재가격 : 9927316.874200001
# 나머지 :  72676
# ======================
# ======================
# 20200707
# 1454
# 판매가 :  217440.41404525744
# 판매갯수 :  44
# 현재잔고 :  9577848.16
# ======================
# ======================
# 20200721
# 901
# 구매가 :  187959.48544573528
# 구매갯수 :  50.0
# 현재가격 : 9397959.482500002
# 나머지 :  179898.16000000015
# ======================
# ======================
# 20200721
# 1444
# 판매가 :  185480.1380150858
# 판매갯수 :  50.0
# 현재잔고 :  9393617.16
# ======================
# ======================
# 20200728
# 1122
# 구매가 :  190244.18022286764
# 구매갯수 :  49.0
# 현재가격 : 9321933.08025
# 나머지 :  71661.16000000015
# ======================
# ======================
# 20200729
# 902
# 판매가 :  189460.2760301716
# 판매갯수 :  49.0
# 현재잔고 :  9294858.15
# ======================
# ======================
# 20200803
# 901
# 구매가 :  175457.61044573528
# 구매갯수 :  52.0
# 현재가격 : 9123780.3618
# 나머지 :  171094.15000000037
# ======================
# ======================
# 20200804
# 1448
# 판매가 :  175980.1380150858
# 판매갯수 :  52.0
# 현재잔고 :  9262572.91
# ======================
# ======================
# 20200807
# 1259
# 구매가 :  179242.53022286764
# 구매갯수 :  51.0
# 현재가격 : 9141335.99475
# 나머지 :  121230.91000000015
# ======================
# ======================
# 20200811
# 1213
# 판매가 :  192980.1380150858
# 판매갯수 :  51.0
# 현재잔고 :  9899238.040000001
# ======================
# ======================
# 20200814
# 1226
# 구매가 :  179742.60522286763
# 구매갯수 :  55.0
# 현재가격 : 9885807.648750002
# 나머지 :  13428.040000000969
# ======================
# ======================
# 20200818
# 901
# 판매가 :  173960.2760301716
# 판매갯수 :  55.0
# 현재잔고 :  9519037.340000002
# ======================
# ======================
# 20200818
# 1247
# 구매가 :  176742.15522286764
# 구매갯수 :  53.0
# 현재가격 : 9367299.88425
# 나머지 :  151711.3400000017
# ======================
# ======================
# 20200826
# 1326
# 판매가 :  172480.1380150858
# 판매갯수 :  53.0
# 현재잔고 :  9233731.980000002
# ======================
# ======================
# 20200828
# 901
# 구매가 :  168240.88022286762
# 구매갯수 :  54.0
# 현재가격 : 9084972.5415
# 나머지 :  148771.9800000023
# ======================
# ======================
# 20200831
# 901
# 판매가 :  169480.1380150858
# 판매갯수 :  54.0
# 현재잔고 :  9241204.500000002
# ======================
# ======================
# 20200901
# 1237
# 구매가 :  170956.9354457353
# 구매갯수 :  54.0
# 현재가격 : 9231658.541100001
# 나머지 :  9580.500000001863
# ======================
# ======================
# 20200908
# 1314
# 판매가 :  189480.1380150858
# 판매갯수 :  54.0
# 현재잔고 :  10174993.020000003
# ======================
# ======================
# 20200910
# 1357
# 구매가 :  190459.86044573528
# 구매갯수 :  53.0
# 현재가격 : 10094356.926450001
# 나머지 :  80666.02000000328
# ======================
# ======================
# 20200911
# 1355
# 판매가 :  173960.2760301716
# 판매갯수 :  53.0
# 현재잔고 :  9240616.800000004
# ======================
# ======================
# 20200915
# 1223
# 구매가 :  172241.48022286763
# 구매갯수 :  53.0
# 현재가격 : 9128764.109250002
# 나머지 :  111843.80000000447
# ======================
# ======================
# 20200918
# 1247
# 판매가 :  169980.1380150858
# 판매갯수 :  53.0
# 현재잔고 :  9062225.690000005
# ======================
# ======================
# 20200923
# 1501
# 구매가 :  161739.90522286764
# 구매갯수 :  56.0
# 현재가격 : 9057398.406000001
# 나머지 :  4841.690000005066
# ======================
# ======================
# 20200928
# 1102
# 판매가 :  157480.1380150858
# 판매갯수 :  56.0
# 현재잔고 :  8766398.970000006
# ======================
# ======================
# 20201005
# 901
# 구매가 :  145737.50522286762
# 구매갯수 :  60.0
# 현재가격 : 8744211.435
# 나머지 :  22178.97000000626
# ======================
# ======================
# 20201006
# 1340
# 판매가 :  140980.1380150858
# 판매갯수 :  60.0
# 현재잔고 :  8425996.770000007
# ======================
# ======================
# 20201006
# 1447
# 구매가 :  140736.75522286762
# 구매갯수 :  59.0
# 현재가격 : 8303430.327750001
# 나머지 :  122572.770000007
# ======================
# ======================
# 20201012
# 1043
# 판매가 :  148980.1380150858
# 판매갯수 :  59.0
# 현재잔고 :  8855258.940000007
# ======================
# ======================
# 20201014
# 903
# 구매가 :  167956.48544573528
# 구매갯수 :  52.0
# 현재가격 : 8733721.8618
# 나머지 :  121546.94000000693
# ======================
# ======================
# 20201015
# 1308
# 판매가 :  147980.1380150858
# 판매갯수 :  52.0
# 현재잔고 :  7766489.700000008
# ======================
# ======================
# 20201021
# 957
# 구매가 :  155238.93022286764
# 구매갯수 :  50.0
# 현재가격 : 7761914.112500001
# 나머지 :  4589.700000007637
# ======================
# ======================
# 20201027
# 1126
# 판매가 :  158480.1380150858
# 판매갯수 :  50.0
# 현재잔고 :  7877083.700000008
# ======================
# ======================
# 20201029
# 901
# 구매가 :  155238.93022286764
# 구매갯수 :  50.0
# 현재가격 : 7761914.112500001
# 나머지 :  115183.70000000764
# ======================
# ======================
# 20201103
# 1207
# 판매가 :  158980.1380150858
# 판매갯수 :  50.0
# 현재잔고 :  8012515.200000008
# ======================
# ======================
# 20201110
# 1047
# 구매가 :  166240.58022286763
# 구매갯수 :  48.0
# 현재가격 : 7979516.748000001
# 나머지 :  32995.20000000764
# ======================
# ======================
# 20201112
# 1459
# 판매가 :  163480.1380150858
# 판매갯수 :  48.0
# 현재잔고 :  7829029.440000008
# ======================
# ======================
# 20201113
# 1127
# 구매가 :  164740.35522286763
# 구매갯수 :  47.0
# 현재가격 : 7742766.240750001
# 나머지 :  86249.44000000786
# ======================
# ======================
# 20201119
# 1518
# 판매가 :  169980.1380150858
# 판매갯수 :  47.0
# 현재잔고 :  8023380.550000008
# ======================
# ======================
# 20201120
# 1329
# 구매가 :  170241.18022286764
# 구매갯수 :  47.0
# 현재가격 : 8001305.015750001
# 나머지 :  22053.550000008196
# ======================
# ======================
# 20201126
# 1055
# 판매가 :  177480.1380150858
# 판매갯수 :  47.0
# 현재잔고 :  8309393.4100000085
# ======================
# ======================
# 20201201
# 1427
# 구매가 :  178742.45522286763
# 구매갯수 :  46.0
# 현재가격 : 8222123.1335
# 나머지 :  87261.41000000853
# ======================
# ======================
# 20201207
# 1401
# 판매가 :  172980.1380150858
# 판매갯수 :  46.0
# 현재잔고 :  7992620.390000009
# ======================
# ======================
# 20201210
# 1441
# 구매가 :  172741.55522286764
# 구매갯수 :  46.0
# 현재가격 : 7946081.733500001
# 나머지 :  46534.39000000898
# ======================
# ======================
# 20201211
# 1221
# 판매가 :  174980.1380150858
# 판매갯수 :  46.0
# 현재잔고 :  8043295.370000009
# ======================
# ======================
# 20201215
# 1459
# 구매가 :  170741.25522286762
# 구매갯수 :  47.0
# 현재가격 : 8024808.540750001
# 나머지 :  18468.370000009425
# ======================
# ======================
# 20201222
# 1422
# 판매가 :  173480.1380150858
# 판매갯수 :  47.0
# 현재잔고 :  8119030.23000001
# ======================
# ======================
# 20201224
# 1520
# 구매가 :  170741.25522286762
# 구매갯수 :  47.0
# 현재가격 : 8024808.540750001
# 나머지 :  94203.23000000976
# ======================
# ======================
# 20201228
# 1211
# 판매가 :  168480.1380150858
# 판매갯수 :  47.0
# 현재잔고 :  7961292.59000001
# ======================
# ======================
# 20201229
# 1456
# 구매가 :  168240.88022286762
# 구매갯수 :  47.0
# 현재가격 : 7907290.915750001
# 나머지 :  54012.590000010096
# ======================
# ======================
# 20210111
# 901
# 판매가 :  157960.2760301716
# 판매갯수 :  47.0
# 현재잔고 :  7429875.810000011
# ======================
# ======================
# 20210111
# 1346
# 구매가 :  155739.00522286762
# 구매갯수 :  47.0
# 현재가격 : 7319702.790750001
# 나머지 :  110142.81000001077
# ======================
# ======================
# 20210114
# 902
# 판매가 :  152960.2760301716
# 판매갯수 :  47.0
# 현재잔고 :  7252533.530000011
# ======================
# ======================
# 20210114
# 1501
# 구매가 :  155238.93022286764
# 구매갯수 :  46.0
# 현재가격 : 7140960.983500001
# 나머지 :  111585.53000001144
# ======================
# ======================
# 20210126
# 901
# 판매가 :  152480.1380150858
# 판매갯수 :  46.0
# 현재잔고 :  7080074.010000012
# ======================
# ======================
# 20210127
# 901
# 구매가 :  152738.55522286764
# 구매갯수 :  46.0
# 현재가격 : 7025943.733500001
# 나머지 :  54126.010000011884
# ======================
# ======================
# 20210129
# 901
# 판매가 :  148480.1380150858
# 판매갯수 :  46.0
# 현재잔고 :  6839810.490000012
# ======================
# ======================
# 20210129
# 1518
# 구매가 :  145737.50522286762
# 구매갯수 :  46.0
# 현재가격 : 6703895.4335
# 나머지 :  135908.49000001233
# ======================
# ======================
# 20210201
# 1247
# 판매가 :  147460.2760301716
# 판매갯수 :  46.0
# 현재잔고 :  6874977.950000012
# ======================
# ======================
# 20210201
# 1320
# 구매가 :  150238.18022286764
# 구매갯수 :  45.0
# 현재가격 : 6760688.951250001
# 나머지 :  114267.9500000123
# ======================
# ======================
# 20210203
# 1455
# 판매가 :  149480.1380150858
# 판매갯수 :  45.0
# 현재잔고 :  6797145.050000013
# ======================
# ======================
# 20210204
# 1318
# 구매가 :  148237.88022286762
# 구매갯수 :  45.0
# 현재가격 : 6670675.451250001
# 나머지 :  126480.05000001285
# ======================
# ======================
# 20210209
# 929
# 판매가 :  149480.1380150858
# 판매갯수 :  45.0
# 현재잔고 :  6809357.150000013
# ======================
# ======================
# 20210209
# 1408
# 구매가 :  150238.18022286764
# 구매갯수 :  45.0
# 현재가격 : 6760688.951250001
# 나머지 :  48647.15000001341
# ======================
# ======================
# 20210219
# 1329
# 판매가 :  148480.1380150858
# 판매갯수 :  45.0
# 현재잔고 :  6686816.750000014
# ======================
# ======================
# 20210303
# 1457
# 구매가 :  113232.63022286764
# 구매갯수 :  59.0
# 현재가격 : 6680686.95275
# 나머지 :  6128.75000001397
# ======================
# ======================
# 20210305
# 901
# 판매가 :  109480.1380150858
# 판매갯수 :  59.0
# 현재잔고 :  6423463.170000014
# ======================
# ======================
# 20210305
# 1255
# 구매가 :  109732.10522286764
# 구매갯수 :  58.0
# 현재가격 : 6364424.520500001
# 나머지 :  59007.170000013895
# ======================
# ======================
# 20210308
# 1102
# 판매가 :  110480.1380150858
# 판매갯수 :  58.0
# 현재잔고 :  6425196.210000014
# ======================
# ======================
# 20210312
# 1508
# 구매가 :  108731.95522286765
# 구매갯수 :  59.0
# 현재가격 : 6415147.127750001
# 나머지 :  10067.210000013933
# ======================
# ======================
# 20210315
# 1222
# 판매가 :  109480.1380150858
# 판매갯수 :  59.0
# 현재잔고 :  6427401.630000014
# ======================
# 6427401.63
# <br/>Waiting for W&B process to finish, PID 25000<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_110537-11evwwbi\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_110537-11evwwbi\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>account</td><td>6427401.63</td></tr><tr><td>_runtime</td><td>39</td></tr><tr><td>_timestamp</td><td>1625623576</td></tr><tr><td>_step</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>account</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">grateful-sweep-3</strong>: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/11evwwbi" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/11evwwbi</a><br/>
# wandb: Agent Starting Run: hywoj5mw with config:
# wandb: 	K_long: 1.2639276722283732
# wandb: 	k_short: 1.5550140607689524
# wandb: 	n_period: 9
#                 Tracking run with wandb version 0.10.33<br/>
#                 Syncing run <strong style="color:#cdcd00">grateful-sweep-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060</a><br/>
#                 Sweep page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/sweeps/8390szpg" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/sweeps/8390szpg</a><br/>
# Run page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/hywoj5mw" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/hywoj5mw</a><br/>
#                 Run data is saved locally in <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_110620-hywoj5mw</code><br/><br/>
# ======================
# 20200707
# 902
# 구매가 :  224617.25356827528
# 구매갯수 :  44
# 현재가격 : 9883134.2478
# 나머지 :  116852
# ======================
# ======================
# 20200707
# 1234
# 판매가 :  221889.9718784621
# 판매갯수 :  44
# 현재잔고 :  9816507.746000001
# ======================
# ======================
# 20200708
# 1209
# 구매가 :  205926.77589206884
# 구매갯수 :  47.0
# 현재가격 : 9678516.55975
# 나머지 :  137985.7460000012
# ======================
# ======================
# 20200709
# 1211
# 판매가 :  212222.49296961553
# 판매갯수 :  47.0
# 현재잔고 :  10047585.925000003
# ======================
# ======================
# 20200714
# 902
# 구매가 :  201294.11726137923
# 구매갯수 :  49.0
# 현재가격 : 9863366.28305
# 나머지 :  184179.9250000026
# ======================
# ======================
# 20200715
# 1428
# 판매가 :  178722.49296961553
# 판매갯수 :  49.0
# 현재잔고 :  8884634.968000002
# ======================
# ======================
# 20200716
# 901
# 구매가 :  180923.02589206884
# 구매갯수 :  49.0
# 현재가격 : 8865184.57825
# 나머지 :  19407.968000002205
# ======================
# ======================
# 20200720
# 1239
# 판매가 :  187222.49296961553
# 판매갯수 :  49.0
# 현재잔고 :  9133655.761000002
# ======================
# ======================
# 20200720
# 1452
# 구매가 :  187160.0336306896
# 구매갯수 :  48.0
# 현재가격 : 8983635.3432
# 나머지 :  149975.7610000018
# ======================
# ======================
# 20200721
# 1040
# 판매가 :  186722.49296961553
# 판매갯수 :  48.0
# 현재잔고 :  9054374.497000001
# ======================
# ======================
# 20200722
# 901
# 구매가 :  192660.85863068962
# 구매갯수 :  46.0
# 현재가격 : 8862355.153900001
# 나머지 :  192014.49700000137
# ======================
# ======================
# 20200723
# 1402
# 판매가 :  184722.49296961553
# 판매갯수 :  46.0
# 현재잔고 :  8633994.619
# ======================
# ======================
# 20200727
# 1235
# 구매가 :  192660.85863068962
# 구매갯수 :  44.0
# 현재가격 : 8477035.3646
# 나머지 :  156954.61900000088
# ======================
# ======================
# 20200729
# 902
# 판매가 :  189722.49296961553
# 판매갯수 :  44.0
# 현재잔고 :  8450462.127
# ======================
# ======================
# 20200803
# 901
# 구매가 :  175290.2172613792
# 구매갯수 :  48.0
# 현재가격 : 8413885.8936
# 나머지 :  36542.12700000033
# ======================
# ======================
# 20200803
# 1454
# 판매가 :  174722.49296961553
# 판매갯수 :  48.0
# 현재잔고 :  8368684.863000001
# ======================
# ======================
# 20200807
# 901
# 구매가 :  180659.05863068963
# 구매갯수 :  46.0
# 현재가격 : 8310272.3539
# 나머지 :  58370.86300000083
# ======================
# ======================
# 20200807
# 1008
# 판매가 :  178222.49296961553
# 판매갯수 :  46.0
# 현재잔고 :  8203294.485000001
# ======================
# ======================
# 20200807
# 1259
# 구매가 :  179158.83363068962
# 구매갯수 :  45.0
# 현재가격 : 8062104.134250001
# 나머지 :  141184.48500000127
# ======================
# ======================
# 20200810
# 1433
# 판매가 :  191722.49296961553
# 판매갯수 :  45.0
# 현재잔고 :  8712595.800000003
# ======================
# ======================
# 20200812
# 1512
# 구매가 :  190660.55863068963
# 구매갯수 :  45.0
# 현재가격 : 8579681.75925
# 나머지 :  132895.8000000026
# ======================
# ======================
# 20200813
# 1109
# 판매가 :  185944.98593923106
# 판매갯수 :  45.0
# 현재잔고 :  8445987.180000003
# ======================
# ======================
# 20200814
# 1226
# 구매가 :  179658.9086306896
# 구매갯수 :  47.0
# 현재가격 : 8443923.39855
# 나머지 :  2061.1800000034273
# ======================
# ======================
# 20200814
# 1308
# 판매가 :  179222.49296961553
# 판매갯수 :  47.0
# 현재잔고 :  8370742.859000004
# ======================
# ======================
# 20200818
# 1247
# 구매가 :  176658.45863068962
# 구매갯수 :  47.0
# 현재가격 : 8302902.248550001
# 나머지 :  67816.8590000039
# ======================
# ======================
# 20200818
# 1438
# 판매가 :  174722.49296961553
# 판매갯수 :  47.0
# 현재잔고 :  8226373.288000004
# ======================
# ======================
# 20200819
# 901
# 구매가 :  171789.6922613792
# 구매갯수 :  47.0
# 현재가격 : 8074071.929150001
# 나머지 :  152290.28800000437
# ======================
# ======================
# 20200824
# 1408
# 판매가 :  165722.49296961553
# 판매갯수 :  47.0
# 현재잔고 :  7890596.217000005
# ======================
# ======================
# 20200825
# 1158
# 구매가 :  171157.6336306896
# 구매갯수 :  46.0
# 현재가격 : 7873206.803900001
# 나머지 :  17374.217000004835
# ======================
# ======================
# 20200825
# 1446
# 판매가 :  172222.49296961553
# 판매갯수 :  46.0
# 현재잔고 :  7888091.839000005
# ======================
# ======================
# 20200826
# 943
# 구매가 :  172657.85863068962
# 구매갯수 :  45.0
# 현재가격 : 7769560.259250001
# 나머지 :  118526.83900000528
# ======================
# ======================
# 20200826
# 1326
# 판매가 :  172222.49296961553
# 판매갯수 :  45.0
# 현재잔고 :  7818141.904000006
# ======================
# ======================
# 20200828
# 901
# 구매가 :  168157.18363068963
# 구매갯수 :  46.0
# 현재가격 : 7735186.1039
# 나머지 :  82919.90400000568
# ======================
# ======================
# 20200831
# 901
# 판매가 :  169222.49296961553
# 판매갯수 :  46.0
# 현재잔고 :  7816534.526000006
# ======================
# ======================
# 20200831
# 1348
# 구매가 :  163656.5086306896
# 구매갯수 :  47.0
# 현재가격 : 7691810.598550001
# 나머지 :  124702.52600000612
# ======================
# ======================
# 20200901
# 1346
# 판매가 :  169722.49296961553
# 판매갯수 :  47.0
# 현재잔고 :  8049786.455000007
# ======================
# ======================
# 20200901
# 1432
# 구매가 :  169657.4086306896
# 구매갯수 :  47.0
# 현재가격 : 7973852.898550001
# 나머지 :  75907.4550000066
# ======================
# ======================
# 20200903
# 1045
# 판매가 :  180722.49296961553
# 판매갯수 :  47.0
# 현재잔고 :  8514630.884000007
# ======================
# ======================
# 20200903
# 1251
# 구매가 :  183159.43363068963
# 구매갯수 :  46.0
# 현재가격 : 8425289.6039
# 나머지 :  89316.88400000706
# ======================
# ======================
# 20200903
# 1452
# 판매가 :  181722.49296961553
# 판매갯수 :  46.0
# 현재잔고 :  8394194.006000008
# ======================
# ======================
# 20200904
# 1143
# 구매가 :  187160.0336306896
# 구매갯수 :  44.0
# 현재가격 : 8234999.064600001
# 나머지 :  159154.00600000843
# ======================
# ======================
# 20200904
# 1244
# 판매가 :  187222.49296961553
# 판매갯수 :  44.0
# 현재잔고 :  8343376.514000009
# ======================
# ======================
# 20200907
# 1027
# 구매가 :  189292.3172613792
# 구매갯수 :  44.0
# 현재가격 : 8328821.135800001
# 나머지 :  14528.514000008814
# ======================
# ======================
# 20200907
# 1346
# 판매가 :  190722.49296961553
# 판매갯수 :  44.0
# 현재잔고 :  8351750.022000009
# ======================
# ======================
# 20200907
# 1511
# 구매가 :  191160.6336306896
# 구매갯수 :  43.0
# 현재가격 : 8219865.794950001
# 나머지 :  131870.0220000092
# ======================
# ======================
# 20200908
# 1314
# 판매가 :  189222.49296961553
# 판매갯수 :  43.0
# 현재잔고 :  8215528.47300001
# ======================
# ======================
# 20200908
# 1451
# 구매가 :  188660.2586306896
# 구매갯수 :  43.0
# 현재가격 : 8112349.669950001
# 나머지 :  103148.47300000954
# ======================
# ======================
# 20200911
# 954
# 판매가 :  177722.49296961553
# 판매갯수 :  43.0
# 현재잔고 :  7695521.17400001
# ======================
# ======================
# 20200911
# 1254
# 구매가 :  175158.23363068962
# 구매갯수 :  43.0
# 현재가격 : 7531762.594950001
# 나머지 :  163727.1740000099
# ======================
# ======================
# 20200911
# 1355
# 판매가 :  174222.49296961553
# 판매갯수 :  43.0
# 현재잔고 :  7606578.12500001
# ======================
# ======================
# 20200911
# 1410
# 구매가 :  174158.08363068962
# 구매갯수 :  43.0
# 현재가격 : 7488756.144950001
# 나머지 :  117784.12500001024
# ======================
# ======================
# 20200914
# 901
# 판매가 :  172944.98593923106
# 판매갯수 :  43.0
# 현재잔고 :  7506038.277000011
# ======================
# ======================
# 20200915
# 1223
# 구매가 :  172157.7836306896
# 구매갯수 :  43.0
# 현재가격 : 7402743.244950001
# 나머지 :  103287.27700001094
# ======================
# ======================
# 20200917
# 1257
# 판매가 :  169222.49296961553
# 판매갯수 :  43.0
# 현재잔고 :  7332535.728000011
# ======================
# ======================
# 20200917
# 1403
# 구매가 :  170157.48363068962
# 구매갯수 :  43.0
# 현재가격 : 7316730.344950001
# 나머지 :  15784.728000011295
# ======================
# ======================
# 20200918
# 1247
# 판매가 :  169722.49296961553
# 판매갯수 :  43.0
# 현재잔고 :  7266393.429000012
# ======================
# ======================
# 20200922
# 1458
# 구매가 :  163656.5086306896
# 구매갯수 :  44.0
# 현재가격 : 7200843.9646000005
# 나머지 :  65529.429000011645
# ======================
# ======================
# 20200923
# 956
# 판매가 :  161222.49296961553
# 판매갯수 :  44.0
# 현재잔고 :  7113187.937000012
# ======================
# ======================
# 20200923
# 1307
# 구매가 :  161656.20863068962
# 구매갯수 :  44.0
# 현재가격 : 7112830.7646
# 나머지 :  323.93700001202524
# ======================
# ======================
# 20200928
# 1102
# ...
# 구매갯수 :  48.0
# 현재가격 : 8582535.1872
# 나머지 :  77867.62700000405
# ======================
# ======================
# 20201207
# 1401
# 판매가 :  172865.71173804582
# 판매갯수 :  48.0
# 현재잔고 :  8321453.747000004
# ======================
# ======================
# 20201210
# 1441
# 구매가 :  172802.47140056285
# 구매갯수 :  48.0
# 현재가격 : 8294491.9872
# 나머지 :  26957.747000004165
# ======================
# ======================
# 20201211
# 1221
# 판매가 :  174865.71173804582
# 판매갯수 :  48.0
# 현재잔고 :  8365919.867000004
# ======================
# ======================
# 20201215
# 1459
# 구매가 :  170802.17140056286
# 구매갯수 :  48.0
# 현재가격 : 8198477.587200001
# 나머지 :  167423.86700000428
# ======================
# ======================
# 20201222
# 1422
# 판매가 :  173365.71173804582
# 판매갯수 :  48.0
# 현재잔고 :  8434853.987000003
# ======================
# ======================
# 20201224
# 1520
# 구매가 :  170802.17140056286
# 구매갯수 :  49.0
# 현재가격 : 8369279.203600001
# 나머지 :  65555.98700000346
# ======================
# ======================
# 20201228
# 1211
# 판매가 :  168365.71173804582
# 판매갯수 :  49.0
# 현재잔고 :  8261816.734500004
# ======================
# ======================
# 20201229
# 1456
# 구매가 :  168301.79640056286
# 구매갯수 :  49.0
# 현재가격 : 8246760.828600001
# 나머지 :  15067.734500003979
# ======================
# ======================
# 20210111
# 901
# 판매가 :  157731.42347609162
# 판매갯수 :  49.0
# 현재잔고 :  7693649.411000004
# ======================
# ======================
# 20210111
# 1346
# 구매가 :  155799.92140056286
# 구매갯수 :  49.0
# 현재가격 : 7634168.953600001
# 나머지 :  59498.41100000404
# ======================
# ======================
# 20210114
# 902
# 판매가 :  152731.42347609162
# 판매갯수 :  49.0
# 현재잔고 :  7494672.587500004
# ======================
# ======================
# 20210120
# 1056
# 구매가 :  146798.57140056285
# 구매갯수 :  51.0
# 현재가격 : 7486698.8364
# 나머지 :  7974.587500004098
# ======================
# ======================
# 20210126
# 901
# 판매가 :  152365.71173804582
# 판매갯수 :  51.0
# 현재잔고 :  7728080.5900000045
# ======================
# ======================
# 20210127
# 901
# 구매가 :  152799.47140056285
# 구매갯수 :  50.0
# 현재가격 : 7639945.82
# 나머지 :  88130.59000000451
# ======================
# ======================
# 20210129
# 901
# 판매가 :  148365.71173804582
# 판매갯수 :  50.0
# 현재잔고 :  7458161.9650000045
# ======================
# ======================
# 20210201
# 1320
# 구매가 :  150299.09640056285
# 구매갯수 :  49.0
# 현재가격 : 7364628.528600001
# 나머지 :  93510.96500000451
# ======================
# ======================
# 20210203
# 1455
# 판매가 :  149365.71173804582
# 판매갯수 :  49.0
# 현재잔고 :  7364823.212500005
# ======================
# ======================
# 20210204
# 1318
# 구매가 :  148298.79640056286
# 구매갯수 :  49.0
# 현재가격 : 7266613.828600001
# 나머지 :  98221.21250000503
# ======================
# ======================
# 20210219
# 1329
# 판매가 :  148365.71173804582
# 판매갯수 :  49.0
# 현재잔고 :  7320851.960000006
# ======================
# ======================
# 20210303
# 1457
# 구매가 :  113293.54640056283
# 구매갯수 :  64.0
# 현재가격 : 7250751.449600001
# 나머지 :  70099.96000000555
# ======================
# ======================
# 20210305
# 901
# 판매가 :  109365.71173804581
# 판매갯수 :  64.0
# 현재잔고 :  7023964.120000006
# ======================
# ======================
# 20210305
# 1255
# 구매가 :  109793.02140056284
# 구매갯수 :  63.0
# 현재가격 : 6916925.383200001
# 나머지 :  107005.1200000057
# ======================
# ======================
# 20210308
# 1102
# 판매가 :  110365.71173804581
# 판매갯수 :  63.0
# 현재잔고 :  7014805.652500006
# ======================
# 7014805.65
# <br/>Waiting for W&B process to finish, PID 24892<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_125646-5hk9xaso\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_125646-5hk9xaso\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>account</td><td>7014805.6525</td></tr><tr><td>_runtime</td><td>100</td></tr><tr><td>_timestamp</td><td>1625630306</td></tr><tr><td>_step</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>account</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">swift-sweep-99</strong>: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/5hk9xaso" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/5hk9xaso</a><br/>
# wandb: Agent Starting Run: tdvgh7v2 with config:
# wandb: 	K_long: 1.0006119085193128
# wandb: 	k_short: 1.5504363153409524
# wandb: 	n_period: 27
#                 Tracking run with wandb version 0.10.33<br/>
#                 Syncing run <strong style="color:#cdcd00">elated-sweep-100</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060</a><br/>
#                 Sweep page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/sweeps/8390szpg" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/sweeps/8390szpg</a><br/>
# Run page: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/tdvgh7v2" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/tdvgh7v2</a><br/>
#                 Run data is saved locally in <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_125832-tdvgh7v2</code><br/><br/>
# ======================
# 20200707
# 902
# 구매가 :  223037.12200183354
# 구매갯수 :  44
# 현재가격 : 9813603.8198
# 나머지 :  186372
# ======================
# ======================
# 20200708
# 901
# 판매가 :  209073.47289630666
# 판매갯수 :  44
# 현재잔고 :  9325789.122000001
# ======================
# ======================
# 20200721
# 901
# 구매가 :  187528.7370003056
# 구매갯수 :  49.0
# 현재가격 : 9188878.125
# 나머지 :  136917.12200000137
# ======================
# ======================
# 20200721
# 1444
# 판매가 :  185224.7818423295
# 판매갯수 :  49.0
# 현재잔고 :  9153899.278000003
# ======================
# ======================
# 20200728
# 1122
# 구매가 :  190028.8060001528
# 구매갯수 :  48.0
# 현재가격 : 9121368.0
# 나머지 :  32555.278000002727
# ======================
# ======================
# 20200729
# 902
# 판매가 :  188949.56368465905
# 판매갯수 :  48.0
# 현재잔고 :  9043155.190000003
# ======================
# ======================
# 20200803
# 901
# 구매가 :  175026.8620003056
# 구매갯수 :  51.0
# 현재가격 : 8926338.75
# 나머지 :  116829.1900000032
# ======================
# ======================
# 20200804
# 1448
# 판매가 :  175724.7818423295
# 판매갯수 :  51.0
# 현재잔고 :  9020500.684000004
# ======================
# ======================
# 20200807
# 1259
# 구매가 :  179027.1560001528
# 구매갯수 :  50.0
# 현재가격 : 8951342.5
# 나머지 :  69150.68400000408
# ======================
# ======================
# 20200813
# 1109
# 판매가 :  185949.56368465905
# 판매갯수 :  50.0
# 현재잔고 :  9306167.259000005
# ======================
# ======================
# 20200818
# 1247
# 구매가 :  176526.7810001528
# 구매갯수 :  52.0
# 현재가격 : 9179376.700000001
# 나머지 :  126815.2590000052
# ======================
# ======================
# 20200826
# 1326
# 판매가 :  172224.7818423295
# 판매갯수 :  52.0
# 현재잔고 :  9024251.547000006
# ======================
# ======================
# 20200828
# 901
# 구매가 :  168025.5060001528
# 구매갯수 :  53.0
# 현재가격 : 8905335.600000001
# 나머지 :  118926.54700000584
# ======================
# ======================
# 20200831
# 901
# 판매가 :  169224.7818423295
# 판매갯수 :  53.0
# 현재잔고 :  9029500.879000006
# ======================
# ======================
# 20200901
# 1237
# 구매가 :  170526.18700030562
# 구매갯수 :  52.0
# 현재가격 : 8867329.9
# 나머지 :  162148.87900000624
# ======================
# ======================
# 20200914
# 901
# 판매가 :  172174.34552698856
# 판매갯수 :  52.0
# 현재잔고 :  9057002.067000007
# ======================
# ======================
# 20200915
# 1223
# 구매가 :  172026.1060001528
# 구매갯수 :  52.0
# 현재가격 : 8945341.600000001
# 나머지 :  111650.06700000726
# ======================
# ======================
# 20200918
# 1247
# 판매가 :  169724.7818423295
# 판매갯수 :  52.0
# 현재잔고 :  8879931.355000008
# ======================
# ======================
# 20200923
# 1501
# 구매가 :  161524.5310001528
# 구매갯수 :  54.0
# 현재가격 : 8722308.15
# 나머지 :  157635.3550000079
# ======================
# ======================
# 20200928
# 1102
# 판매가 :  157224.7818423295
# 판매갯수 :  54.0
# 현재잔고 :  8592545.731000008
# ======================
# ======================
# 20201006
# 1129
# 구매가 :  141021.4560001528
# 구매갯수 :  60.0
# 현재가격 : 8461269.0
# 나머지 :  131285.73100000806
# ======================
# ======================
# 20201006
# 1340
# 판매가 :  140724.7818423295
# 판매갯수 :  60.0
# 현재잔고 :  8519843.371000009
# ======================
# ======================
# 20201007
# 1410
# 구매가 :  141521.5310001528
# 구매갯수 :  60.0
# 현재가격 : 8491273.5
# 나머지 :  28583.371000008658
# ======================
# ======================
# 20201015
# 1308
# 판매가 :  147724.7818423295
# 판매갯수 :  60.0
# 현재잔고 :  8834411.01100001
# ======================
# ======================
# 20201019
# 901
# 구매가 :  152523.7930004584
# 구매갯수 :  57.0
# 현재가격 : 8693803.875
# 나머지 :  140600.01100000925
# ======================
# ======================
# 20201019
# 1359
# 판매가 :  153224.7818423295
# 판매갯수 :  57.0
# 현재잔고 :  8817598.51900001
# ======================
# ======================
# 20201021
# 957
# 구매가 :  155023.5560001528
# 구매갯수 :  56.0
# 현재가격 : 8681302.0
# 나머지 :  136310.51900001056
# ======================
# ======================
# 20201028
# 1203
# 판매가 :  156224.7818423295
# 판매갯수 :  56.0
# 현재잔고 :  8827988.98300001
# ======================
# ======================
# 20201029
# 901
# 구매가 :  155023.5560001528
# 구매갯수 :  56.0
# 현재가격 : 8681302.0
# 나머지 :  146700.98300001025
# ======================
# ======================
# 20201110
# 904
# 판매가 :  162348.69105397715
# 판매갯수 :  56.0
# 현재잔고 :  9179094.31100001
# ======================
# ======================
# 20201112
# 1409
# 구매가 :  163524.8310001528
# 구매갯수 :  56.0
# 현재가격 : 9157373.4
# 나머지 :  21750.31100001
# ======================
# ======================
# 20201112
# 1459
# 판매가 :  163224.7818423295
# 판매갯수 :  56.0
# 현재잔고 :  9102880.77500001
# ======================
# ======================
# 20201113
# 1127
# 구매가 :  164524.9810001528
# 구매갯수 :  55.0
# 현재가격 : 9048857.125
# 나머지 :  54060.775000009686
# ======================
# ======================
# 20201119
# 1518
# 판매가 :  169724.7818423295
# 판매갯수 :  55.0
# 현재잔고 :  9328204.44500001
# ======================
# ======================
# 20201120
# 1329
# 구매가 :  170025.8060001528
# 구매갯수 :  54.0
# 현재가격 : 9181377.0
# 나머지 :  146854.4450000096
# ======================
# ======================
# 20201126
# 1055
# 판매가 :  177224.7818423295
# 판매갯수 :  54.0
# 현재잔고 :  9654744.82100001
# ======================
# ======================
# 20201201
# 1427
# 구매가 :  178527.0810001528
# 구매갯수 :  54.0
# 현재가격 : 9640445.850000001
# 나머지 :  14286.821000009775
# ======================
# ======================
# 20201207
# 1401
# 판매가 :  172724.7818423295
# 판매갯수 :  54.0
# 현재잔고 :  9280756.69700001
# ======================
# ======================
# 20201210
# 1441
# 구매가 :  172526.1810001528
# 구매갯수 :  53.0
# 현재가격 : 9143871.375
# 나머지 :  136878.69700000994
# ======================
# ======================
# 20201211
# 1221
# 판매가 :  174724.7818423295
# 판매갯수 :  53.0
# 현재잔고 :  9337058.27900001
# ======================
# ======================
# 20201215
# 1459
# 구매가 :  170525.8810001528
# 구매갯수 :  54.0
# 현재가격 : 9208381.05
# 나머지 :  128708.27900001034
# ======================
# ======================
# 20201222
# 1422
# 판매가 :  173224.7818423295
# 판매갯수 :  54.0
# 현재잔고 :  9422002.65500001
# ======================
# ======================
# 20201224
# 1520
# 구매가 :  170525.8810001528
# 구매갯수 :  55.0
# 현재가격 : 9378906.625
# 나머지 :  43127.655000010505
# ======================
# ======================
# 20201228
# 1211
# 판매가 :  168224.7818423295
# 판매갯수 :  55.0
# 현재잔고 :  9235307.57500001
# ======================
# ======================
# 20201229
# 1456
# 구매가 :  168025.5060001528
# 구매갯수 :  54.0
# 현재가격 : 9073360.8
# 나머지 :  161957.57500001043
# ======================
# ======================
# 20210111
# 1313
# 판매가 :  155224.7818423295
# 판매갯수 :  54.0
# 현재잔고 :  8489569.95100001
# ======================
# ======================
# 20210111
# 1346
# 구매가 :  155523.6310001528
# 구매갯수 :  54.0
# 현재가격 : 8398259.55
# 나머지 :  91327.9510000106
# ======================
# ======================
# 20210126
# 901
# 판매가 :  152224.7818423295
# 판매갯수 :  54.0
# 현재잔고 :  8257993.327000011
# ======================
# ======================
# 20210127
# 901
# 구매가 :  152523.1810001528
# 구매갯수 :  54.0
# 현재가격 : 8236235.250000001
# 나머지 :  21751.32700001076
# ======================
# ======================
# 20210129
# 901
# 판매가 :  148224.7818423295
# 판매갯수 :  54.0
# 현재잔고 :  7973820.703000011
# ======================
# ======================
# 20210129
# 1518
# 구매가 :  145522.1310001528
# 구매갯수 :  54.0
# 현재가격 : 7858178.550000001
# 나머지 :  115632.70300001092
# ======================
# ======================
# 20210203
# 1455
# 판매가 :  149224.7818423295
# 판매갯수 :  54.0
# 현재잔고 :  8121351.079000011
# ======================
# ======================
# 20210204
# 1318
# 구매가 :  148022.5060001528
# 구매갯수 :  54.0
# 현재가격 : 7993198.800000001
# 나머지 :  128163.07900001109
# ======================
# ======================
# 20210219
# 1329
# 판매가 :  148224.7818423295
# 판매갯수 :  54.0
# 현재잔고 :  8080232.455000011
# ======================
# ======================
# 20210303
# 1457
# 구매가 :  113017.2560001528
# 구매갯수 :  71.0
# 현재가격 : 8024203.450000001
# 나머지 :  56025.45500001125
# ======================
# ======================
# 20210305
# 901
# 판매가 :  109224.78184232952
# 판매갯수 :  71.0
# 현재잔고 :  7760522.579000012
# ======================
# ======================
# 20210305
# 1255
# 구매가 :  109516.73100015281
# 구매갯수 :  70.0
# 현재가격 : 7666149.750000001
# 나머지 :  94402.57900001202
# ======================
# ======================
# 20210308
# 1102
# 판매가 :  110224.78184232952
# 판매갯수 :  70.0
# 현재잔고 :  7759930.659000012
# ======================
# ======================
# 20210312
# 1508
# 구매가 :  108516.58100015282
# 구매갯수 :  71.0
# 현재가격 : 7704655.525
# 나머지 :  55294.65900001209
# ======================
# ======================
# 20210315
# 1222
# 판매가 :  109224.78184232952
# 판매갯수 :  71.0
# 현재잔고 :  7759791.783000013
# ======================
# 7759791.78
# <br/>Waiting for W&B process to finish, PID 18596<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_125832-tdvgh7v2\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Desktop\Desktop\주가예측\wandb\run-20210707_125832-tdvgh7v2\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>account</td><td>7759791.783</td></tr><tr><td>_runtime</td><td>100</td></tr><tr><td>_timestamp</td><td>1625630412</td></tr><tr><td>_step</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>account</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">elated-sweep-100</strong>: <a href="https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/tdvgh7v2" target="_blank">https://wandb.ai/yeongu/dual_SK%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C_%EB%B6%84%EB%8B%A8%EC%9C%84_%EB%85%BC%EB%AC%B8_%EC%B5%9C%EB%8C%8060/runs/tdvgh7v2</a><br/>

# %%
# 논문 그대로

import pandas as pd
import numpy
import csv

def train_theme(config=None):
    
    column_name = ['기업명', '기업코드', '날짜','시간','시가', '고가', '저가', '종가', '거래량'] # 데이터의 열 지정
    result = {}
    
     # Start a new run, tracking hyperparameters in config
    with wandb.init(config=config):
        config=wandb.config

        dataframe = pd.read_csv(rf'C:\Users\Desktop\Desktop\주가예측\주식데이터\SK바이오팜_train.csv',encoding='cp949') # 코로나 대폭락을 제외한 데이터
        data = dataframe.values.tolist()

        new_dataframe = pd.DataFrame(data, columns=column_name) # 데이터에 열 지정
        new_dataframe = new_dataframe.dropna(axis=0)
        new_dataframe = new_dataframe.reset_index()


        next_day = 0


        buyline = []
        sellLine = []

        while next_day < len(new_dataframe)-config.n_period:
            HH = 0
            LC = 0
            HC = 0
            LL = 0

            HH_array = []
            LC_array = []
            HC_array = []
            LL_array = []

            before_day = next_day + 1

            for n in range(config.n_period):
                HH_array.append(new_dataframe['고가'][before_day+n])
                LC_array.append(new_dataframe['종가'][before_day+n])
                HC_array.append(new_dataframe['종가'][before_day+n])
                LL_array.append(new_dataframe['저가'][before_day+n])


            HH = max(HH_array)
            LC = min(LC_array)
            HC = max(HC_array)
            LL = min(LL_array)

            trigger = max(HH - LC , HC - LL) # 0 = 다음날 1 = 이전날

            buyline_temp = new_dataframe['시가'][next_day] + config.K_long * trigger
            sellLine_temp = new_dataframe['시가'][next_day] - config.k_short * trigger

            buyline.append(buyline_temp)
            sellLine.append(sellLine_temp)


            next_day = next_day+1



        for n in range(config.n_period):
            buyline.append(0)
            sellLine.append(0)



        new_dataframe.insert(0,"longLine",buyline,True) # 다음날 대비 등락률율을 해당날에 넣었음 . 즉 , 당일 기사와 당일 등락률을 비교!
        new_dataframe.insert(0,"shortLine",sellLine,True) # 다음날 대비 등락률율을 해당날에 넣었음 . 즉 , 당일 기사와 당일 등락률을 비교!

        idx_positive = new_dataframe[new_dataframe['longLine']==0].index
        new_dataframe = new_dataframe.drop(idx_positive) # 떨어진 날의 데이터를 제거)


        # test

        # 1천만원
        account = 10000000
        buy_num = 0
        sell_num = 0
        sell_price = 0


        buy = False

        buy_price_all = []
        sell_price_all = []


        # i = 0
        # k = 0

        for i in range(len(new_dataframe)-1,0,-1):

            if(new_dataframe['shortLine'][i] == new_dataframe['longLine'][i]):
                sell_price_all.append(new_dataframe['시가'][i])
                buy_price_all.append(new_dataframe['시가'][i])
                continue

            if(int(new_dataframe['shortLine'][i]) == 0):
                print("0000")
                continue

           # 위 line을 넘어가면 buy
            if(new_dataframe['고가'][i] >= new_dataframe['longLine'][i]):
        #         if(short):
        #             account = new_dataframe['shortLine'][i] * short_num + left
                if(buy==False):
                    buy_num = account//int(new_dataframe['longLine'][i] * 1.00015)
                    left = account - buy_num * int(new_dataframe['longLine'][i] * 1.00015)
                    print("======================")
                    print(new_dataframe["날짜"][i])
                    print(new_dataframe["시간"][i])
                    print("구매가 : ",new_dataframe['longLine'][i] * 1.00015)
                    buy_price_all.append(new_dataframe['longLine'][i])
                    sell_price_all.append(new_dataframe['시가'][i])
                    print("구매갯수 : ", buy_num)
                    print("현재가격 :", buy_num * int(new_dataframe['longLine'][i]) * 1.00015)
                    print("나머지 : ", left)
                    print("======================")
                    buy = True
                else :
                    sell_price_all.append(new_dataframe['시가'][i])
                    buy_price_all.append(new_dataframe['시가'][i])

                      # 아래 line을 넘어가면 sell
            elif(new_dataframe['저가'][i] <= new_dataframe['shortLine'][i]):
                if(buy):
                    buy = False
                    sell_price = buy_num * int(new_dataframe['shortLine'][i])
                    account = sell_price * 0.9935 + left
                    print("======================")
                    print(new_dataframe["날짜"][i])
                    print(new_dataframe["시간"][i])
                    print("판매가 : ",new_dataframe['shortLine'][i])
                    sell_price_all.append(new_dataframe['shortLine'][i])
                    buy_price_all.append(new_dataframe['시가'][i])
                    print("판매갯수 : ", buy_num)
                    print("현재잔고 : ", account)
                    print("======================")
                else :
                    sell_price_all.append(new_dataframe['시가'][i])
                    buy_price_all.append(new_dataframe['시가'][i])
                

            else:
                sell_price_all.append(new_dataframe['시가'][i])
                buy_price_all.append(new_dataframe['시가'][i])


        #     i+=1

        #         sell = True

        #         short_num = account//int(new_dataframe['shortLine'][i])
        #         short_price = int(new_dataframe['shortLine'][i])
        #         left = account - short_num * int(new_dataframe['shortLine'][i])
        #         print("short",short_num)

        sell_price_all.reverse()
        buy_price_all.reverse()
        print(round(account,2))
        wandb.log({"account": account})
#         result[stock] = round(account,2)

# %%
sweep_config = {
    'method': 'bayes'
}

metric={
      'goal': 'maximize',
      'name': 'account'
}

sweep_config['metric'] = metric

parameters_dict = {
}

sweep_config['parameters'] = parameters_dict

parameters_dict.update({
    'n_period': {
        'max': 60, # 1 ~ 갯수의 평균x2 까지
        'min': 3
    },
      'K_long': {
        'distribution': 'uniform',
        'max': 2.0, # 평균 비율 ~ X2 까지
        'min': 1.0
      },
      'k_short': {
        'distribution': 'uniform',
        'max': 2.0 , # 1 ~ 평균 까지
        'min': 1.0
      }
})


pprint.pprint(sweep_config)

sweep_id = wandb.sweep(sweep_config, project=f"dual_휴마시스_분단위_MY_최대60")
# Out:
# {'method': 'bayes',
#  'metric': {'goal': 'maximize', 'name': 'account'},
#  'parameters': {'K_long': {'distribution': 'uniform', 'max': 2.0, 'min': 1.0},
#                 'k_short': {'distribution': 'uniform', 'max': 2.0, 'min': 1.0},
#                 'n_period': {'max': 60, 'min': 3}}}
# Create sweep with ID: 524jwzbe
# Sweep URL: https://wandb.ai/yeongu/dual_%ED%9C%B4%EB%A7%88%EC%8B%9C%EC%8A%A4_%EB%B6%84%EB%8B%A8%EC%9C%84_MY_%EC%B5%9C%EB%8C%8060/sweeps/524jwzbe

# %%
wandb.agent(sweep_id, train, count=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-658fb9371a8e> in <module>
# ----> 1 wandb.agent(sweep_id, train, count=200)
#
# NameError: name 'train' is not defined

# %%
# 논문과 반대

import pandas as pd
import numpy
import csv

def train(config=None):
    
    column_name = ['기업명', '기업코드', '날짜','시간' ,'시가', '고가', '저가', '종가', '거래량'] # 데이터의 열 지정
    result = {}
    
     # Start a new run, tracking hyperparameters in config
    with wandb.init(config=config):
        config=wandb.config

        dataframe = pd.read_csv(rf'C:\Users\Desktop\Desktop\주가예측\주식데이터\휴마시스_train.csv',encoding='cp949') # 코로나 대폭락을 제외한 데이터
        data = dataframe.values.tolist()

        new_dataframe = pd.DataFrame(data, columns=column_name) # 데이터에 열 지정
        new_dataframe = new_dataframe.dropna(axis=0)
        new_dataframe = new_dataframe.reset_index()


        next_day = 0


        buyline = []
        sellLine = []

        while next_day < len(new_dataframe)-config.n_period:
            HH = 0
            LC = 0
            HC = 0
            LL = 0

            HH_array = []
            LC_array = []
            HC_array = []
            LL_array = []

            before_day = next_day + 1

            for n in range(config.n_period):
                HH_array.append(new_dataframe['고가'][before_day+n])
                LC_array.append(new_dataframe['종가'][before_day+n])
                HC_array.append(new_dataframe['종가'][before_day+n])
                LL_array.append(new_dataframe['저가'][before_day+n])


            HH = max(HH_array)
            LC = min(LC_array)
            HC = max(HC_array)
            LL = min(LL_array)

            trigger = max(HH - LC , HC - LL) # 0 = 다음날 1 = 이전날

            buyline_temp = new_dataframe['시가'][next_day] + config.K_long * trigger
            sellLine_temp = new_dataframe['시가'][next_day] - config.k_short * trigger

            buyline.append(buyline_temp)
            sellLine.append(sellLine_temp)


            next_day = next_day+1



        for n in range(config.n_period):
            buyline.append(0)
            sellLine.append(0)



        new_dataframe.insert(0,"longLine",buyline,True) # 다음날 대비 등락률율을 해당날에 넣었음 . 즉 , 당일 기사와 당일 등락률을 비교!
        new_dataframe.insert(0,"shortLine",sellLine,True) # 다음날 대비 등락률율을 해당날에 넣었음 . 즉 , 당일 기사와 당일 등락률을 비교!

        idx_positive = new_dataframe[new_dataframe['longLine']==0].index
        new_dataframe = new_dataframe.drop(idx_positive) # 떨어진 날의 데이터를 제거)


        # test

        # 1천만원
        account = 10000000
        buy_num = 0
        sell_num = 0
        sell_price = 0


        buy = False

        buy_price_all = []
        sell_price_all = []


        # i = 0
        # k = 0

        for i in range(len(new_dataframe)-1,0,-1):

            if(new_dataframe['shortLine'][i] == new_dataframe['longLine'][i]):
                sell_price_all.append(new_dataframe['시가'][i])
                buy_price_all.append(new_dataframe['시가'][i])
                continue

            if(int(new_dataframe['shortLine'][i]) == 0):
                print("0000")
                continue

                      # 아래 line을 넘어가면 buy
            if(new_dataframe['저가'][i] <= new_dataframe['shortLine'][i]):
                if(buy==False):
                    buy_num = account//int(new_dataframe['shortLine'][i]*1.00015)
                    left = account - buy_num * int(new_dataframe['shortLine'][i]*1.00015)
                    print("======================")
                    print(new_dataframe["날짜"][i])
                    print(new_dataframe["시간"][i])
                    print("구매가 : ",new_dataframe['shortLine'][i]*1.00015)
                    buy_price_all.append(new_dataframe['shortLine'][i])
                    sell_price_all.append(new_dataframe['시가'][i])
                    print("구매갯수 : ", buy_num)
                    print("현재가격 :", buy_num * int(new_dataframe['shortLine'][i]*1.00015))
                    print("나머지 : ", left)
                    print("======================")
                    buy = True
                else :
                    sell_price_all.append(new_dataframe['시가'][i])
                    buy_price_all.append(new_dataframe['시가'][i])

            # 위 line을 넘어가면 sell
            elif(new_dataframe['고가'][i] >= new_dataframe['longLine'][i]):
        #         if(short):
        #             account = new_dataframe['shortLine'][i] * short_num + left
                if(buy):
                    buy = False
                    sell_price = buy_num * int(new_dataframe['longLine'][i])
                    account = sell_price * 0.9935 + left
                    print("======================")
                    print(new_dataframe["날짜"][i])
                    print(new_dataframe["시간"][i])
                    print("판매가 : ",new_dataframe['longLine'][i])
                    sell_price_all.append(new_dataframe['longLine'][i])
                    buy_price_all.append(new_dataframe['시가'][i])
                    print("판매갯수 : ", buy_num)
                    print("현재잔고 : ", account)
                    print("======================")
                else :
                    sell_price_all.append(new_dataframe['시가'][i])
                    buy_price_all.append(new_dataframe['시가'][i])

            else:
                sell_price_all.append(new_dataframe['시가'][i])
                buy_price_all.append(new_dataframe['시가'][i])

        #         # 사거나 판 날 다음만 비교해야함!!
        #         k+1



        #     i+=1

        #         sell = True

        #         short_num = account//int(new_dataframe['shortLine'][i])
        #         short_price = int(new_dataframe['shortLine'][i])
        #         left = account - short_num * int(new_dataframe['shortLine'][i])
        #         print("short",short_num)

        sell_price_all.reverse()
        buy_price_all.reverse()
        print(round(account,2))
        wandb.log({"account": account})
#         result[stock] = round(account,2)
